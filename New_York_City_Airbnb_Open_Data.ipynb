# %% [markdown]
# <a href="https://colab.research.google.com/github/Nataliaa1994/data-science/blob/master/New_York_City_Airbnb_Open_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-14036311-c6e9-49f9-ae57-d6418cb0ce15" name="files[]" multiple disabled />
#      <output id="result-14036311-c6e9-49f9-ae57-d6418cb0ce15">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving AB_NYC_2019.csv to AB_NYC_2019 (1).csv

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-778a1bb2-19e4-4c2f-887f-3d6f480ef1f6" name="files[]" multiple disabled />
#      <output id="result-778a1bb2-19e4-4c2f-887f-3d6f480ef1f6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving New_York_City_.png to New_York_City_.png

# %%
pip install matplotlib

import matplotlib.pyplot as plt
import matplotlib.image as mpimg


img = mpimg.imread('New_York_City_.png')
img

# %%
plt.imshow(img)

# %%
import io
data = pd.read_csv(io.StringIO(uploaded['AB_NYC_2019.csv'].decode('utf-8')))

# %%
data.head(5)
# Out:
#      id  ... availability_365
# 0  2539  ...              365
# 1  2595  ...              355
# 2  3647  ...              365
# 3  3831  ...              194
# 4  5022  ...                0
#
# [5 rows x 16 columns]

# %%
fig=px.scatter_mapbox(data, )

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
data.describe()
# Out:
#                  id  ...  availability_365
# count  4.889500e+04  ...      48895.000000
# mean   1.901714e+07  ...        112.781327
# std    1.098311e+07  ...        131.622289
# min    2.539000e+03  ...          0.000000
# 25%    9.471945e+06  ...          0.000000
# 50%    1.967728e+07  ...         45.000000
# 75%    2.915218e+07  ...        227.000000
# max    3.648724e+07  ...        365.000000
#
# [8 rows x 10 columns]

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
plt.figure(figsize=(20, 10))
img = cv2.imread("New_York_City_.png")
img_cvt=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_cvt)
plt.show()

# %%
data.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64
